# %% [markdown]
# <a href="https://colab.research.google.com/github/zszazi/MSD/blob/master/MSD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MSD intern

# %% [markdown]
# ## upload images
#
# I had some problem with navigating through image in google colab
# so I locally downloaded few images and tried template matching on it

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-f182b3eb-f725-4cbf-9a7c-c37236a51429" name="files[]" multiple disabled />
#      <output id="result-f182b3eb-f725-4cbf-9a7c-c37236a51429">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving crop11.jpg to crop11 (1).jpg
# Saving image11.jpg to image11 (2).jpg
# User uploaded file "crop11.jpg" with length 9974 bytes
# User uploaded file "image11.jpg" with length 74579 bytes

# %% [markdown]
# ## Import required libraries

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %% [markdown]
# Change the name of uploaded image and crop file

# %%
img = cv2.imread('image11.jpg',0)
img2 = img.copy()
template = cv2.imread('crop11.jpg',0)
w, h = template.shape[::-1]

# %% [markdown]
# # There are total 6 inbuilt methods for template matching

# %% [markdown]
# **1.   TM_CCOEFF**
#
# **2.   TM_CCOEFF_NORMED**
#
# **3.   TM_CCORR**
#
# **4.   TM_CCORR_NORMED**
#
# **5.   TM_SQDIFF**
#
# **6.   TM_SQDIFF_NORMED**

# %%
methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR',
            'cv2.TM_CCORR_NORMED', 'cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED']

for meth in methods:
    img = img2.copy()
    method = eval(meth)

    # Apply template Matching
    res = cv2.matchTemplate(img,template,method)
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)

    # If the method is TM_SQDIFF or TM_SQDIFF_NORMED, take minimum
    if method in [cv2.TM_SQDIFF, cv2.TM_SQDIFF_NORMED]:
        top_left = min_loc
    else:
        top_left = max_loc
    bottom_right = (top_left[0] + w, top_left[1] + h)

    cv2.rectangle(img,top_left, bottom_right, 255, 4)

    plt.subplot(121),plt.imshow(res,cmap = 'gray')
    plt.title('Matching Result'), plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(img,cmap = 'gray')
    plt.title('Detected Point'), plt.xticks([]), plt.yticks([])
    plt.suptitle(meth)

    plt.show()
    
    cv2_imshow(img)
    
    # PRINT The Coordinates
    print(min_val,max_val,min_loc,max_loc)
# Out:
# <PIL.Image.Image image mode=L size=400x600 at 0x7F64059CF8D0>
# -24615556.0 28876666.0 (11, 1) (101, 199)
# <PIL.Image.Image image mode=L size=400x600 at 0x7F64059CFAC8>
# -0.4136885702610016 0.3770569860935211 (37, 12) (102, 199)
# <PIL.Image.Image image mode=L size=400x600 at 0x7F6404E4DC88>
# 158274400.0 303128192.0 (116, 190) (0, 81)
# <PIL.Image.Image image mode=L size=400x600 at 0x7F640577EDA0>
# 0.6673038005828857 0.8097569942474365 (50, 193) (0, 425)
# <PIL.Image.Image image mode=L size=400x600 at 0x7F6404E8C630>
# 168978704.0 763961984.0 (104, 199) (0, 54)
# <PIL.Image.Image image mode=L size=400x600 at 0x7F6404E99438>
# 0.7565264701843262 1.0 (103, 199) (0, 0)

# %% [markdown]
# # Incase if the crop is not found in the image

# %%
files.upload()
# Out:
#      <input type="file" id="files-0f8e3d54-f720-400a-b4c3-f62c343e3b0c" name="files[]" multiple disabled />
#      <output id="result-0f8e3d54-f720-400a-b4c3-f62c343e3b0c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving crop_not_found.jpg to crop_not_found (1).jpg
# {'crop_not_found.jpg': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x01\x01\x01\x02\x01\x01\x01\x02\x02\x02\x02\x02\x04\x03\x02\x02\x02\x02\x05\x04\x04\x03\x04\x06\x05\x06\x06\x06\x05\x06\x06\x06\x07\t\x08\x06\x07\t\x07\x06\x06\x08\x0b\x08\t\n\n\n\n\n\x06\x08\x0b\x0c\x0b\n\x0c\t\n\n\n\xff\xdb\x00C\x01\x02\x02\x02\x02\x02\x02\x05\x03\x03\x05\n\x07\x06\x07\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n
xf3\x13\xfb\xd4\xc0u\x14\xc1<e\xb6g\x07\xde\x9f@\x05\x14Q@\x05\x14SZUS\xb4\x83@\x0e\xa2\x9b\xe7G\x8c\xee\xfc)U\x83\x0c\x8a\x996\x90\x0cx\x99\x98\xb0"\x98\xcaT\xed4\xe9/m\xa2\x90\xc5$\xa0\x11\xd4\x1a\xadq\xaa\xe9\xb1\xb9\xdf}\x18>\x84\xd6|\xf2\x01\xba\x83\xb4677\x0c\x0e\x12\x06*G\xd2\xbf)?\xe0\xac\xbf\xb6n\x8d\xfb<\xf8\x16\xf3_\xba\xd4\x02\xdfO\x1d\xd46\x16\xe7\x04\xc8\xc5p\xc7\x92>\xe8 \x9f@E~\xa1x\xd3\xc5\xdau\xaf\x86\xafc\x82\xe9Y\x8d\xbb\x05\xdb\xd8\xe2\xbf\x9b_\xf8/_\xc5\x89\xbcq\xf1O@\xf05\xb5\xfaN\xbad\xf7\xa6x\xd7\x92\xbfhTI3\xff\x00\x00D#\xeaiI\xb9-@\xfc\xff\x00\xf1&\xa3\xe2\x9f\x88\xde!\xba\xf17\x88/..&\x9er\xfet\xfc\xb0\xcfo\xa0\xe8=\x80\xabZo\xc2\xbbi\xa7I\xd7{\x9e\xa5\xa4\xe35\xb1\xa3[\x19KC\xe6\x96\x0c\xd9\x0c\x05v\xbe\x1f\xd1\x91\xca\x05\xdex\xeb\x8a\x9eT\x075\'\xc3{)!\x02XH\xe3\xa2\x8a\xcb\xbe\xf8]\xa7J\xae\x90C( pH\x18\xafe\xb2\xf0\xa43\xc6\x1eP\xfd9\xc0\xa2\xeb\xc2v\xae\x00\x81\\z\xee\x14r\xa14\x99\xf3\xbd\xf7\xc3\xedR\xd5U \xb6g\nNH\x1e\ ...

# %%
img = cv2.imread('image11.jpg',0)
img2 = img.copy()
template = cv2.imread('crop_not_found.jpg',0)
w, h = template.shape[::-1]

# %%
methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR',
            'cv2.TM_CCORR_NORMED', 'cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED']

for meth in methods:
    img = img2.copy()
    method = eval(meth)

    # Apply template Matching
    res = cv2.matchTemplate(img,template,method)
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)

    # If the method is TM_SQDIFF or TM_SQDIFF_NORMED, take minimum
    if method in [cv2.TM_SQDIFF, cv2.TM_SQDIFF_NORMED]:
        top_left = min_loc
    else:
        top_left = max_loc
    bottom_right = (top_left[0] + w, top_left[1] + h)

    cv2.rectangle(img,top_left, bottom_right, 255, 2)

    plt.subplot(121),plt.imshow(res,cmap = 'gray')
    plt.title('Matching Result'), plt.xticks([]), plt.yticks([])
    plt.subplot(122),plt.imshow(img,cmap = 'gray')
    plt.title('Detected Point'), plt.xticks([]), plt.yticks([])
    plt.suptitle(meth)

    plt.show()
    
    cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=400x600 at 0x7F64063D1198>
# <PIL.Image.Image image mode=L size=400x600 at 0x7F64065A3C88>
# <PIL.Image.Image image mode=L size=400x600 at 0x7F6405A79DA0>
# <PIL.Image.Image image mode=L size=400x600 at 0x7F6405A792B0>
# <PIL.Image.Image image mode=L size=400x600 at 0x7F64059C3668>
# <PIL.Image.Image image mode=L size=400x600 at 0x7F640577E9E8>
